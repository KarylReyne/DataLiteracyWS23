# %%
import matplotlib.pyplot as plt
from tueplots.constants.color import rgb
from tueplots import bundles
import school_analysis.plotting.germany_heatmap_lib as heatmaplib

#plt.rcParams.update(bundles.icml2022(column="full", nrows=1, ncols=2, usetex=False))


plotter = heatmaplib.GermanStatesHeatmapPlot()
heatmap_dictionary = {
    "Baden-Württemberg": 1.1,
    "Bayern": -0.8,
    "Berlin": None,
    "Brandenburg": -1.0,
    "Bremen": 0.5,
    "Hamburg": -0.3,
    "Hessen": 1.2,
    "Mecklenburg-Vorpommern": -0.4,
    "Niedersachsen": 0.9,
    "Nordrhein-Westfalen": -1.2,
    "Rheinland-Pfalz": 0.2,
    "Saarland": -0.7,
    "Sachsen": 0.8,
    "Sachsen-Anhalt": -0.6,
    "Schleswig-Holstein": 1.0,
    "Thüringen": -0.9
}

fig,ax,cbar = plotter.create_plot(heatmap_dictionary,default_state_color="gray")
ax.set_title("Random Heatmap Values")
cbar.set_label("Demo Value Range")
plt.show()
